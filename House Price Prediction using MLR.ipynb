# %%
#IMPORTING LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#READING DATASET
data = pd.read_csv("kc_house_data.csv")
#READ BY 19BIT0203

# %%
#DESCRIPTION OF DATASET BY (RITWIK RISHABH 19BIT0203)
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21611.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.396095     291.509045   1971.005136     84.402258
# std        1.175459    828.128162     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
#NO. OF ROWS AND COLUMNS IN THE DATASET
data.shape
# Out:
# (21613, 21)

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
#CORRECTIONS IN DATE, BATHROOMS AND FLOORS ATTRIBUTES (19BIT0203)
data['date']=pd.to_datetime(data["date"])
data['bathrooms'] = np.round(data['bathrooms'])
data['floors'] = np.round(data['floors'])
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3        1.0         1180
# 1  6414100192 2014-12-09  538000.0         3        2.0         2570
# 2  5631500400 2015-02-25  180000.0         2        1.0          770
# 3  2487200875 2014-12-09  604000.0         4        3.0         1960
# 4  1954400510 2015-02-18  510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
#INFORMATION OF DATASET
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(14)
# memory usage: 3.5 MB

# %%
#FINDING COUNT OF NULL VALUES OF EACH ATTRIBUTE 
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       2
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#DISPLAYING ROWS WITH NULL PRICE VALUE
data[data['sqft_above'].isnull()]
# Out:
#             id       date     price  bedrooms  bathrooms  sqft_living  \
# 10  1736800520 2015-04-03  662500.0         3        2.0         3560
# 17  6865200140 2014-05-29  485000.0         4        1.0         1600
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 10      9796     1.0           0     0  ...      8         NaN           1700
# 17      4300     2.0           0     0  ...      7         NaN              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 10      1965             0    98007  47.6007 -122.145           2210
# 17      1916             0    98103  47.6648 -122.343           1610
#
#     sqft_lot15
# 10        8925
# 17        4300
#
# [2 rows x 21 columns]

# %%
#REPLACING THE NULL VALUES WITH MEAN OF PRICE
data['sqft_above'] = data['sqft_above'].fillna(data['sqft_above'].mean())
data.iloc[[10,17]]
# Out:
#             id       date     price  bedrooms  bathrooms  sqft_living  \
# 10  1736800520 2015-04-03  662500.0         3        2.0         3560
# 17  6865200140 2014-05-29  485000.0         4        1.0         1600
#
#     sqft_lot  floors  waterfront  view  ...  grade   sqft_above  \
# 10      9796     1.0           0     0  ...      8  1788.396095
# 17      4300     2.0           0     0  ...      7  1788.396095
#
#     sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 10           1700      1965             0    98007  47.6007 -122.145
# 17              0      1916             0    98103  47.6648 -122.343
#
#     sqft_living15  sqft_lot15
# 10           2210        8925
# 17           1610        4300
#
# [2 rows x 21 columns]

# %%
#CHECKING FOR ANY DUPLICATE RECORDS
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
#VISUALISING HISTOGRAM FOR CHECKING SKEWNESS (LEFT SKEWED)
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(data['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
#VISULATISING WHISKER PLOT/BOX PLOT TO CHECK FOR OUTLIERS
fig=plt.gcf()
fig.set_size_inches(10,5)
sns.boxplot(x=data['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
#BOX PLOT ANALYSIS
Q1 = data['price'].quantile(0.25)
Q3 = data['price'].quantile(0.75)
IQR = Q3-Q1
MIN = Q1-1.5*IQR
MAX = Q3+1.5*IQR
filter= (data['price']< MIN) | (data['price']>MAX)
print('1st Quartile = ',Q1,'\n3rd Quatiile = ',Q3,'\nInter Quartile Range = ',IQR,'\nMinimum = ',MIN,'\nMaximum = ',MAX)
# Out:
# 1st Quartile =  321950.0
# 3rd Quatiile =  645000.0
# Inter Quartile Range =  323050.0
# Minimum =  -162625.0
# Maximum =  1129575.0

# %%
#DISPLAYING THE OUTLIERS 
data['price'][filter]
# Out:
# 5        1225000.0
# 21       2000000.0
# 49       1350000.0
# 69       1325000.0
# 125      1450000.0
#            ...
# 21568    1700000.0
# 21576    3567000.0
# 21590    1222500.0
# 21597    1575000.0
# 21600    1537000.0
# Name: price, Length: 1146, dtype: float64

# %%
#FILTERING OUT THE 1146 OUTLIERS IN THE DATA (19bit0203)
data_clean = data[(data['price']<=MAX) & (data['price']>=MIN)]
fig=plt.gcf()
fig.set_size_inches(10,5)
#DISPLAYING THE BOX PLOT AFTER REMOVAL OF OUTLIERS
sns.boxplot(x=data_clean['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
#CAPPING THE OUTLIERS 
data_clean_cap = data.copy()
data_clean_cap['price'] = np.where(data['price'] > MAX,MAX, np.where(data['price'] < MIN, MIN, data['price']))
fig=plt.gcf()
fig.set_size_inches(10,5)
sns.boxplot(x=data_clean_cap['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
#NUMBER OF ROWS REDUCED FROM 21613 TO 20467 AFTER OUTLIER REMOVAL
data_clean.shape
# Out:
# (20467, 21)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.histplot(data_clean['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
#NUMBER OF ROWS REDUCED FROM 21613 TO 20467 AFTER OUTLIER REMOVAL
data_clean.shape
# Out:
# (20467, 21)

# %%
#CORRELATION ANALYSIS
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(data_clean.corr(), annot=True, cmap=sns.diverging_palette(220, 10, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
#DROPPING 'sqft_living', 'sqft_lot15'
data_p = data_clean_cap.drop(['sqft_living','sqft_lot15'], axis = 1)
#'id' AND 'zipcode' ARE NOT REQUIRED FOR PREDICTION HENCE WE DROP THEM TOO
p_data = data_p.drop(['id','zipcode','date'],axis=1)
p_data.head(5)
# Out:
#       price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 0  221900.0         3        1.0      5650     1.0           0     0
# 1  538000.0         3        2.0      7242     2.0           0     0
# 2  180000.0         2        1.0     10000     1.0           0     0
# 3  604000.0         4        3.0      5000     1.0           0     0
# 4  510000.0         3        2.0      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7      1180.0              0      1955             0
# 1          3      7      2170.0            400      1951          1991
# 2          3      6       770.0              0      1933             0
# 3          5      7      1050.0            910      1965             0
# 4          3      8      1680.0              0      1987             0
#
#        lat     long  sqft_living15
# 0  47.5112 -122.257           1340
# 1  47.7210 -122.319           1690
# 2  47.7379 -122.233           2720
# 3  47.5208 -122.393           1360
# 4  47.6168 -122.045           1800

# %%
#HEATMAP AFTER DROPPING THE CORRELATED FEATURES
fig, ax = plt.subplots(figsize=(14,14))
sns.heatmap(p_data.corr(), annot=True, cmap=sns.diverging_palette(220, 10, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(16,24))

plt.subplot(3,2,1)
sns.regplot(data=data_clean, x='sqft_living15', y='price')

plt.subplot(3,2,2)
sns.regplot(data=data_clean, x='sqft_lot', y='price')

plt.subplot(3,2,3)
sns.regplot(data=data_clean, x='sqft_above', y='price')

plt.subplot(3,2,4)
sns.regplot(data=data_clean, x='sqft_basement', y='price')

plt.subplot(3,2,5)
sns.regplot(data=data_clean, x='bedrooms', y='price')

plt.subplot(3,2,6)
sns.regplot(data=data_clean, x='floors', y='price')

plt.show()

# %%
#SEPARATING DEPENDENT VARIABLE (CLASS LABEL) FROM INDEPENDENT VARIABLES :-
pp_data = p_data.copy()
y = pp_data['price'] #CLASS LABEL
x = pp_data.drop(['price'],axis=1) #MULTIPLE INDEPENDENT ATTRIBUTES
#SPLITTING THE DATASET INTO TRAINING AND TESTING DATA :-
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1,random_state = 2)
print('Rows and Columns :- \nx_train : ',x_train.shape,'\nx_test : ',x_test.shape,'\ny_train : ',y_train.shape,'\ny_test : ',y_test.shape)
# Out:
# Rows and Columns :-
# x_train :  (19451, 15)
# x_test :  (2162, 15)
# y_train :  (19451,)
# y_test :  (2162,)

# %%
#MUTLTI LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
print('TRAIN SCORE : ',reg.score(x_train,y_train))
print('TEST SCORE : ',reg.score(x_test,y_test))
# Out:
# TRAIN SCORE :  0.7430736520889798
# TEST SCORE :  0.7632880163361065

# %%
y_pred = reg.predict(x_test)
df = pd.DataFrame({'Actual price': y_test, 'Predicted price': y_pred})
df
# Out:
#        Actual price  Predicted price
# 6638       735000.0     6.316176e+05
# 7366      1129575.0     9.159633e+05
# 3158       350500.0     3.993298e+05
# 9117       860000.0     1.001346e+06
# 3392       122000.0     4.143575e+04
# ...             ...              ...
# 3823       294950.0     4.115622e+05
# 3268       732000.0     6.422467e+05
# 19051      299000.0     2.628060e+05
# 1486       229950.0     2.587728e+05
# 10955      571000.0     4.653907e+05
#
# [2162 rows x 2 columns]

# %%
from sklearn.metrics import r2_score,mean_squared_error
mse = mean_squared_error(y_test,y_pred).round(2) #VARIANCE
rmse = np.sqrt(mse).round(2) #STANDARD DEVIATION
rSq = r2_score(y_test, y_pred).round(2) 
print('MEAN SQUARE ERROR : ',mse,'\nROOT MEAN SQUARED ERROR : ',rmse,'\nR SQUARED : ',rSq)
# Out:
# MEAN SQUARE ERROR :  15230005872.66
# ROOT MEAN SQUARED ERROR :  123409.91
# R SQUARED :  0.76
